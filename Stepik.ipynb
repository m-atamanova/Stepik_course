# %% [markdown]
# **SEP**

# %%
print('I', 'like', 'Python', sep='***')
# Out:
# I***like***Python

# %%
name = input ()
print('Привет,', name, end='!')
# Out:
# Maria
# Привет, Maria!

# %%
end1 = input()
a = input()
b = input()
c = input()
print(a, end=end1)
print(b, end=end1)
print(c, end='')
# Out:
# 2
# 3
# 4
# 5
# 32425
